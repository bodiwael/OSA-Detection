# %%
# import required modules
import firebase_admin
from firebase_admin import db, credentials

# %%
# !pip install firebase_admin

# %%
cred = credentials.Certificate('/kaggle/input/credentials/credentials.json')
firebase_admin.initialize_app(cred, {"databaseURL": "https://osa-detection-default-rtdb.firebaseio.com/"})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 2
#       1 cred = credentials.Certificate('/kaggle/input/credentials/credentials.json')
# ----> 2 firebase_admin.initialize_app(cred, {"databaseURL": "https://osa-detection-default-rtdb.firebaseio.com/"})
#
# File /opt/conda/lib/python3.10/site-packages/firebase_admin/__init__.py:71, in initialize_app(credential, options, name)
#      68         return app
#      70 if name == _DEFAULT_APP_NAME:
# ---> 71     raise ValueError((
#      72         'The default Firebase app already exists. This means you called '
#      73         'initialize_app() more than once without providing an app name as '
#      74         'the second argument. In most cases you only need to call '
#      75         'initialize_app() once. But if you do want to initialize multiple '
# ...

# %%
# creating reference to root node
Age = db.reference("Data/Age")

Weight = db.reference("Data/Weight")

Height = db.reference("Data/Height")

Gender = db.reference("Data/Gender")

SPO2 = db.reference("Data/SPO2")

HR = db.reference("Data/HR")

# %%
# retrieving data from root node
age = Age.get()
weight = Weight.get()
height = Height.get()
gender = Gender.get()
spo2 = SPO2.get()
hr = HR.get()

print(gender)
# Out:
# "male"

# %%
BMI = int(weight) / (int(height) ** 2)

# %%
db.reference("/").update({"language": "python"})

# update operation (add new key value)
db.reference("/").update({"subscribed": True})

# %%
print(gender)
# Out:
# "male"

# %%
'''
Test Cases:
65 99 51 Female 18 FALSE
85 96 70 Male 40.1 TRUE
'''
# Out:
# '\nTest Cases:\n65 99 51 Female 18 FALSE\n85 96 70 Male 40.1 TRUE\n'

# %%
import pandas as pd
import joblib

model_path = "/kaggle/input/random-forest-model/rf_model.pkl"

loaded_model = joblib.load(model_path)

gender_mapping = {"male": 0, "female": 1}
gender_num = gender_mapping.get(gender.lower(), -1)
        
new_data = {'HR': hr, 'SpO2': spo2, 'Age': age, 'Gender': gender_num, 'BMI': BMI}

# Convert the data to a feature vector
feature_vector = pd.DataFrame([new_data])

rf_predictions = loaded_model.predict(feature_vector)

print(rf_predictions[0])
# Out:
# True

# %%
while(True):
    # creating reference to root node
    age = Age.get()
    weight = Weight.get()
    height = Height.get()
    gender = Gender.get()
    spo2 = SPO2.get()
    hr = HR.get()
        
    BMI = int(weight) / (int(height) ** 2)
    
    model_path = "/kaggle/input/random-forest-model/rf_model.pkl"

    loaded_model = joblib.load(model_path)

    gender_mapping = {"male": 0, "female": 1}
    gender_num = gender_mapping.get(gender.lower(), -1)

    new_data = {'HR': hr, 'SpO2': spo2, 'Age': age, 'Gender': gender_num, 'BMI': BMI}

    # Convert the data to a feature vector
    feature_vector = pd.DataFrame([new_data])

    rf_predictions = loaded_model.predict(feature_vector)

    print(rf_predictions[0])
    
    if(rf_predictions[0] == True):
        db.reference("/Data/OSA").set(1)
    else:
        db.reference("/Data/OSA").set(0)
# Out:
# 30
# False
# 30
# False
# 30
# False
# 30
# False
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[43], line 3
#       1 while(True):
#       2     # creating reference to root node
# ----> 3     age = Age.get()
#       4     weight = Weight.get()
#       5     height = Height.get()
#
# File /opt/conda/lib/python3.10/site-packages/firebase_admin/db.py:221, in Reference.get(self, etag, shallow)
#     218     return data, headers.get('ETag')
#     220 params = 'shallow=true' if shallow else None
# --> 221 return self._client.body('get', self._add_suffix(), params=params)
#
# File /opt/conda/lib/python3.10/site-packages/firebase_admin/_http_client.py:131, in HttpClient.body(self, method, url, **kwargs)
#     130 def body(self, method, url, **kwargs):
# --> 131     resp = self.request(method, url, **kwargs)
#     132     return self.parse_body(resp)
#
# ...
